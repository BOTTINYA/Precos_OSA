# %% [markdown]
# # Notebook for visualizing data

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
def preco_features(df):
    features = df.drop(['Ventes'], axis=1)
    feature_names = list(features)
    return features, feature_names
    
def preco_target(df):
    target = pd.DataFrame(df['Ventes'])
    target_name = list(target)
    return target, target_name

# %%
df = pd.read_csv('BDD_Promo.csv', sep = ';')
df = df[df['Ventes'] > 0]
df = df.dropna()

_,feature_names = preco_features(df)
_,target_name = preco_target(df)

print('List of feature names:\n', feature_names, '\nTarget name:\n',target_name)
# Out:
# List of feature names:
#  ['Annee', 'Type_Offre', 'Code_Produit', 'Previ_Volume', 'Nb_Jours', 'S_debut', 'UB', 'Taux_Degradation', 'Magasin', 'VMH', 'Baseline_Magasin', 'Nb_Codes', 'Produit_Source']
# Target name:
#  ['Ventes']

# %%
# ------------- Description statistique du data set d'entrainement -------------
df.describe().transpose()
# Out:
#                      count         mean          std     min          25%  \
# Annee             324154.0  2017.709928     0.722844  2017.0  2017.000000
# Type_Offre        324154.0    61.497112   219.121146     1.0    10.000000
# Code_Produit      324154.0   354.635664   576.200354     1.0    86.000000
# Previ_Volume      324154.0    20.148247    35.402874     0.0     5.000000
# Nb_Jours          324154.0    10.881050     3.543189     6.0     9.000000
# S_debut           324154.0    22.018482    15.172713     0.0     8.000000
# UB                324154.0    15.217733    12.291173     1.0     7.000000
# Taux_Degradation  324154.0    24.194735    13.385902     0.0    25.000000
# Magasin           324154.0   108.372274    61.944288     1.0    55.000000
# VMH               324154.0  2780.613329  3508.252919  -375.0  1000.000000
# Ventes            324154.0   110.660961   149.619960     1.0    30.000000
# Baseline_Magasin  324154.0    85.763257   112.630416     0.0    27.146743
# Nb_Codes          324154.0    28.203804    22.339832     1.0    12.000000
# Produit_Source    324154.0   335.370318   552.502532     1.0    84.000000
#
#                           50%          75%            max
# Annee             2018.000000  2018.000000    2019.000000
# Type_Offre          10.000000    13.000000    1000.000000
# Code_Produit       192.000000   322.000000    2944.000000
# Previ_Volume         9.900000    22.000000     813.000000
# Nb_Jours             9.000000    16.000000      19.000000
# S_debut             20.000000    35.000000      52.000000
# UB                  10.000000    25.000000      51.000000
# Taux_Degradation    30.000000    33.000000      50.000000
# Magasin            108.000000   162.000000     215.000000
# VMH               1680.000000  3292.000000  133875.000000
# Ventes              64.000000   131.000000    4253.000000
# Baseline_Magasin    51.421295    96.738637    3778.983747
# Nb_Codes            22.000000    35.000000      84.000000
# Produit_Source     190.000000   295.000000    2944.000000

# %%
for i in feature_names:
    plt.title('Distribution plot for "'+i+'"')
    sns.distplot(df[i])
    plt.show()
