# %% [markdown]
# # Modèle Auchan

# %%
run main
# Out:
# Sur quelle enseigne voulez-vous travailler ? (Carrefour/Auchan) Auchan
# Souhaitez-vous ré-entrainer le modèle ? (Y/n) y
# Souhaitez-vous ré-entrainer le modèle pour déploiement ou phase de test ? (Y pour deploiement/ n pour phase de test) n
# Querying BigQuery for training data...
# Querying and loading time = 98.77 s
# Request finished
#
# Cleaning Data...
# Data cleansing done
#
# Transforming skewed columns for Normal distribution approximation...
#
# Performing training data encoding
# Feature encoding...
# Feature encoding done
#
# Data encoding finished
#
# Affichage de la distribution des données
# Affichage de la corrélation des colonnes
# Voulez-vous faire un tuning automatique des Hyperparamètres du modèle ? (Y/n) n
# Training a XGBoost model
# [0]	train-rmse:3.31068	eval-rmse:3.31479
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 10 rounds.
# ...

# %% [markdown]
# # Modèle Carrefour

# %%
run main
# Out:
# Sur quelle enseigne voulez-vous travailler ? (Carrefour/Auchan) Carrefour
# Souhaitez-vous ré-entrainer le modèle ? (Y/n) y
# Souhaitez-vous ré-entrainer le modèle pour déploiement ou phase de test ? (Y pour deploiement/ n pour phase de test) n
# Querying BigQuery for training data...
# Querying and loading time = 127.17 s
# Request finished
#
# Cleaning Data...
# Data cleansing done
#
# Transforming skewed columns for Normal distribution approximation...
#
# Performing training data encoding
# Feature encoding...
# Feature encoding done
#
# Data encoding finished
#
# Affichage de la distribution des données
# Affichage de la corrélation des colonnes
# Voulez-vous faire un tuning automatique des Hyperparamètres du modèle ? (Y/n) n
# Training a XGBoost model
# [0]	train-rmse:3.32344	eval-rmse:3.32499
# Multiple eval metrics have been passed: 'eval-rmse' will be used for early stopping.
#
# Will train until eval-rmse hasn't improved in 10 rounds.
# ...
